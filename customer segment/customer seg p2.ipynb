# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("E:\chromedownload\ifood_df.csv")
df
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# Load and display an image
img = mpimg.imread("D:\chrome download\OneDrive\Pictures\dictionary.png")
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
pip install --upgrade pandas seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="p2 Profiling Report", explorative=True)
profile.to_file("p2_profile_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.isnull().sum()
# Out:
# Income                  0
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# Age                     0
# Customer_Days           0
# marital_Divorced        0
# marital_Married         0
# marital_Single          0
# marital_Together        0
# marital_Widow           0
# education_2n Cycle      0
# education_Basic         0
# education_Graduation    0
# education_Master        0
# ...

# %%
df.duplicated().sum()
# Out:
# 184

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Income                  float64
# Kidhome                   int64
# Teenhome                  int64
# Recency                   int64
# MntWines                  int64
# MntFruits                 int64
# MntMeatProducts           int64
# MntFishProducts           int64
# MntSweetProducts          int64
# MntGoldProds              int64
# NumDealsPurchases         int64
# NumWebPurchases           int64
# NumCatalogPurchases       int64
# NumStorePurchases         int64
# NumWebVisitsMonth         int64
# AcceptedCmp3              int64
# AcceptedCmp4              int64
# AcceptedCmp5              int64
# AcceptedCmp1              int64
# AcceptedCmp2              int64
# Complain                  int64
# Z_CostContact             int64
# Z_Revenue                 int64
# Response                  int64
# Age                       int64
# Customer_Days             int64
# marital_Divorced          int64
# marital_Married           int64
# marital_Single            int64
# ...

# %%
df
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2198  26816.0        0         0       50         5          1
# 2200  61223.0        0         1       46       709         43
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2021 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Income                2021 non-null   float64
#  1   Kidhome               2021 non-null   int64
#  2   Teenhome              2021 non-null   int64
#  3   Recency               2021 non-null   int64
#  4   MntWines              2021 non-null   int64
#  5   MntFruits             2021 non-null   int64
#  6   MntMeatProducts       2021 non-null   int64
#  7   MntFishProducts       2021 non-null   int64
#  8   MntSweetProducts      2021 non-null   int64
#  9   MntGoldProds          2021 non-null   int64
#  10  NumDealsPurchases     2021 non-null   int64
#  11  NumWebPurchases       2021 non-null   int64
#  12  NumCatalogPurchases   2021 non-null   int64
#  13  NumStorePurchases     2021 non-null   int64
#  14  NumWebVisitsMonth     2021 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2021.000000  2021.000000  2021.000000  2021.000000  2021.000000
# mean    51687.258783     0.443345     0.509649    48.880752   306.492331
# std     20713.046401     0.536196     0.546393    28.950917   337.603877
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35416.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51412.000000     0.000000     0.000000    49.000000   178.000000
# 75%     68274.000000     1.000000     1.000000    74.000000   507.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2021.000000      2021.000000      2021.000000       2021.000000
# mean     26.364671       166.059871        37.603662         27.268679
# std      39.776518       219.869126        54.892196         41.575454
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response', 'Age', 'Customer_Days', 'marital_Divorced', 'marital_Married', 'marital_Single', 'marital_Together', 'marital_Widow', 'education_2n Cycle', 'education_Basic', 'education_Graduation', 'education_Master', 'education_PhD', 'MntTotal', 'MntRegularProds', 'AcceptedCmpOverall']

# %% [markdown]
# #### Average purchase amount

# %%
avg_purchase_value = df['MntTotal'].mean()
print("The average purchase value is",avg_purchase_value)
# Out:
# The average purchase value is 563.789213260762

# %% [markdown]
# #### Average Income

# %%
avg_income = df['Income'].mean()
print("The average Income is",avg_income)
# Out:
# The average Income is 51687.2587827808

# %%
mode=df.mode()
print("The mode value is",mode)
# Out:
# The mode value is    Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  MntMeatProducts  \
# 0  7500.0      0.0       0.0     56.0       2.0        0.0              5.0
# 1     NaN      NaN       NaN      NaN       NaN        NaN              7.0
# 2     NaN      NaN       NaN      NaN       NaN        NaN              NaN
# 3     NaN      NaN       NaN      NaN       NaN        NaN              NaN
# 4     NaN      NaN       NaN      NaN       NaN        NaN              NaN
# 5     NaN      NaN       NaN      NaN       NaN        NaN              NaN
#
#    MntFishProducts  MntSweetProducts  MntGoldProds  ...  marital_Together  \
# 0              0.0               0.0           3.0  ...               0.0
# 1              NaN               NaN           NaN  ...               NaN
# 2              NaN               NaN           NaN  ...               NaN
# 3              NaN               NaN           NaN  ...               NaN
# ...

# %%
df.shape
# Out:
# (2021, 39)

# %%
df.dtypes
# Out:
# Income                  float64
# Kidhome                   int64
# Teenhome                  int64
# Recency                   int64
# MntWines                  int64
# MntFruits                 int64
# MntMeatProducts           int64
# MntFishProducts           int64
# MntSweetProducts          int64
# MntGoldProds              int64
# NumDealsPurchases         int64
# NumWebPurchases           int64
# NumCatalogPurchases       int64
# NumStorePurchases         int64
# NumWebVisitsMonth         int64
# AcceptedCmp3              int64
# AcceptedCmp4              int64
# AcceptedCmp5              int64
# AcceptedCmp1              int64
# AcceptedCmp2              int64
# Complain                  int64
# Z_CostContact             int64
# Z_Revenue                 int64
# Response                  int64
# Age                       int64
# Customer_Days             int64
# marital_Divorced          int64
# marital_Married           int64
# marital_Single            int64
# ...

# %%
df.nunique()
# Out:
# Income                  1963
# Kidhome                    3
# Teenhome                   3
# Recency                  100
# MntWines                 775
# MntFruits                158
# MntMeatProducts          551
# MntFishProducts          182
# MntSweetProducts         176
# MntGoldProds             212
# NumDealsPurchases         15
# NumWebPurchases           15
# NumCatalogPurchases       13
# NumStorePurchases         14
# NumWebVisitsMonth         16
# AcceptedCmp3               2
# AcceptedCmp4               2
# AcceptedCmp5               2
# AcceptedCmp1               2
# AcceptedCmp2               2
# Complain                   2
# Z_CostContact              1
# Z_Revenue                  1
# Response                   2
# Age                       56
# Customer_Days            662
# marital_Divorced           2
# marital_Married            2
# marital_Single             2
# marital_Together           2
# marital_Widow              2
# education_2n Cycle         2
# ...

# %% [markdown]
# #### Percentage of Customers Accepting Campaigns

# %%
df["campaing"]=df[["AcceptedCmp1","AcceptedCmp2","AcceptedCmp3","AcceptedCmp4","AcceptedCmp5"]].sum(axis=1)
campaing_per=df["campaing"].value_counts(normalize=True)*100
print(campaing_per)
# Out:
# campaing
# 0    78.921326
# 1    14.893617
# 2     3.711034
# 3     1.979218
# 4     0.494805
# Name: proportion, dtype: float64

# %% [markdown]
# #### Average Income by Education Level

# %%
df["Education"]=df[["education_2n Cycle","education_Basic","education_Graduation","education_Master","education_PhD"]].sum(axis=1)

# %%
income_stats = df.groupby('Education')['Income'].agg(['mean', 'median', 'std'])
print(income_stats)
# Out:
#                    mean   median           std
# Education
# 1          51687.258783  51412.0  20713.046401

# %% [markdown]
# #### Correlation

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_df.corr()

print(corr_matrix)
# Out:
#                         Income   Kidhome  Teenhome   Recency  MntWines  \
# Income                1.000000 -0.540774  0.044418  0.001105  0.724708
# Kidhome              -0.540774  1.000000 -0.050093  0.020118 -0.506500
# Teenhome              0.044418 -0.050093  1.000000  0.020180  0.003875
# Recency               0.001105  0.020118  0.020180  1.000000  0.011484
# MntWines              0.724708 -0.506500  0.003875  0.011484  1.000000
# MntFruits             0.535848 -0.374275 -0.178776 -0.012252  0.382979
# MntMeatProducts       0.697477 -0.446086 -0.266716  0.016184  0.587013
# MntFishProducts       0.549806 -0.389791 -0.199319 -0.001318  0.391603
# MntSweetProducts      0.552832 -0.376579 -0.164658  0.023051  0.382027
# MntGoldProds          0.407378 -0.352719 -0.017015  0.011669  0.388793
# NumDealsPurchases    -0.135717  0.218667  0.383452  0.009301  0.016442
# NumWebPurchases       0.495144 -0.382000  0.152427 -0.005093  0.547999
# ...

# %%
data=df["Age"]<=100
data
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 2198    True
# 2200    True
# 2202    True
# 2203    True
# 2204    True
# Name: Age, Length: 2021, dtype: bool

# %% [markdown]
# #### customers have children or teenagers

# %%
#0 - no children/teen 1-count of child /teen
print(df[['Kidhome', 'Teenhome']].value_counts())
# Out:
# Kidhome  Teenhome
# 0        1           571
#          0           567
# 1        0           456
#          1           337
# 0        2            28
# 2        1            24
# 1        2            21
# 2        0            17
# Name: count, dtype: int64

# %%
#There are 957 customers who made 1 purchases using deals.
print(df['NumDealsPurchases'].value_counts())
# Out:
# NumDealsPurchases
# 1     868
# 2     455
# 3     272
# 4     176
# 5      84
# 6      57
# 0      35
# 7      33
# 8      14
# 9       7
# 15      5
# 10      5
# 11      5
# 13      3
# 12      2
# Name: count, dtype: int64

# %%
df["marital_Divorced"]=df['marital_Divorced'].replace({1:"divorced"})
df["marital_Married"]=df['marital_Married'].replace({1:"married"})
df["marital_Single"]=df['marital_Single'].replace({1:"single"})
df["marital_Together"]=df['marital_Together'].replace({1:"relationship"})
df["marital_Widow"]=df['marital_Widow'].replace({1:"widow"})

# %% [markdown]
# #### Percentage of Customers Who Are Married

# %%
df['marital_Married'].value_counts(normalize=True)
# Out:
# marital_Married
# 0    0.611578
# 1    0.388422
# Name: proportion, dtype: float64

# %% [markdown]
# #### Average Spending by married and no-married people on different Products

# %%
df[df['Income'] > 50000].groupby("marital_Married")[['MntWines', 'MntMeatProducts', 'MntFishProducts']].mean()
# Out:
#                    MntWines  MntMeatProducts  MntFishProducts
# marital_Married
# 0                532.696401       296.904538        64.735524
# 1                510.801435       269.858852        58.373206

# %%
df["AcceptedCmp1"]=df['AcceptedCmp1'].replace({0:"accepted",1:"denied"})
df["AcceptedCmp2"]=df['AcceptedCmp2'].replace({0:"accepted",1:"denied"})
df["AcceptedCmp3"]=df['AcceptedCmp3'].replace({0:"accepted",1:"denied"})
df["AcceptedCmp4"]=df['AcceptedCmp4'].replace({0:"accepted",1:"denied"})
df["AcceptedCmp5"]=df['AcceptedCmp5'].replace({0:"accepted",1:"denied"})
df["Complain"]=df['Complain'].replace({1:"complained",0:"otherwise"})

# %% [markdown]
# #### Customers have made purchases within the last 10 days

# %%
df[df["Recency"]<=10].shape[0]
# Out:
# 238

# %% [markdown]
# #### success rate of the last marketing campaign

# %%
df["Response"]=df['Response'].replace({0:"otherwise",1:"accepted"})

# %%
success_rate = df['Response'].value_counts(normalize=True)
success_rate
# Out:
# Response
# otherwise    0.846116
# accepted     0.153884
# Name: proportion, dtype: float64

# %% [markdown]
# #### Outliers detect and remove

# %%
plt.figure(figsize=(6, 4))  
sns.boxplot(data=df, y='MntTotal')
plt.title('Box Plot for MntTotal')
plt.ylabel('MntTotal')
plt.show()

# %%
Q1 = df['MntTotal'].quantile(0.25)
Q3 = df['MntTotal'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['MntTotal'] < lower_bound) | (df['MntTotal'] > upper_bound)]
outliers.head()
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 1159  90638.0        0         0       29      1156        120
# 1467  87679.0        0         0       62      1259        172
# 1547  90638.0        0         0       29      1156        120
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 1159              915               94               144            96  ...
# 1467              815               97               148            33  ...
# 1547              915               94               144            96  ...
#
#       education_2n Cycle  education_Basic  education_Graduation  \
# 1159                   0                0                     0
# 1467                   0                0                     1
# 1547                   0                0                     0
#
#       education_Master  education_PhD MntTotal MntRegularProds  \
# 1159                 1              0     2429            2333
# ...

# %%
data = df[(df['MntTotal'] > lower_bound) & (df['MntTotal'] < upper_bound)]
data.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2018.000000  2018.000000  2018.000000  2018.000000  2018.000000
# mean    51630.820119     0.444004     0.510406    48.893954   305.178394
# std     20676.523136     0.536322     0.546445    28.964198   336.123164
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35395.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51400.500000     0.000000     0.000000    49.000000   177.500000
# 75%     68138.000000     1.000000     1.000000    74.000000   505.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2018.000000      2018.000000      2018.000000       2018.000000
# mean     26.199703       164.996036        37.518335         27.093162
# std      39.563725       218.284750        54.888293         41.356022
# ...

# %%
data = data[(data['MntTotal'] > lower_bound) & (data['MntTotal'] < upper_bound)]
data.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2018.000000  2018.000000  2018.000000  2018.000000  2018.000000
# mean    51630.820119     0.444004     0.510406    48.893954   305.178394
# std     20676.523136     0.536322     0.546445    28.964198   336.123164
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35395.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51400.500000     0.000000     0.000000    49.000000   177.500000
# 75%     68138.000000     1.000000     1.000000    74.000000   505.000000
# max    113734.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2018.000000      2018.000000      2018.000000       2018.000000
# mean     26.199703       164.996036        37.518335         27.093162
# std      39.563725       218.284750        54.888293         41.356022
# ...

# %% [markdown]
# ### Visualization

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(8,6))
sns.histplot(x="Age", data=df,color="blue",bins=20)
plt.title('Age distribuation of customer')
plt.xlabel('Age')
plt.ylabel('number of customers')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(x="Income", data=df,color="blue",kde=True)
plt.title("Income Distribution of Customers")
plt.xlabel('Number of customers')
plt.ylabel('Income')
plt.show()

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,n_init=10)
df['Cluster'] = kmeans.fit_predict(df[['Age', 'Income']])

plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='Age', y='Income', hue='Cluster', palette='Set2')
plt.title('Customer Segments by Age and Income')
plt.show()

# %%
sns.lmplot(data=df, x='Kidhome', y='MntTotal')
plt.title('Impact of Kids at Home on Spending')
plt.show()

# %%
def get_marital_status(row):
    if row['marital_Divorced'] == 1:
        return 'Divorced'
    elif row['marital_Married'] == 1:
        return 'Married'
    elif row['marital_Single'] == 1:
        return 'Single'
    elif row['marital_Together'] == 1:
        return 'Together'
    elif row['marital_Widow'] == 1:
        return 'Widow'
    else:
        return 'Unknown'
data['Marital'] = data.apply(get_marital_status, axis=1)

# %%
sns.barplot(data=data, x='Education', y='MntTotal',hue="Marital", palette='muted') 
plt.title('Spending by Marital Status')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Marital', y='MntTotal', data=data, palette='muted')
plt.title('MntTotal by marital status')
plt.xlabel('Marital status')
plt.ylabel('MntTotal')
# Out:
# Text(0, 0.5, 'MntTotal')

# %%
sns.boxplot(data=data, x='Marital', y='MntTotal', palette='muted') 
plt.title('Spending by Marital Status')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Education', y='MntWines', data=data, hue="Marital")

plt.title('Wine Spending by Education Level and Marital Status')
plt.xlabel('Education')
plt.ylabel('Amount Spent on Wine')
plt.show()
