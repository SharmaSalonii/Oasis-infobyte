# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("E:\chromedownload\WineQT (1).csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# fixed acidity             91
# volatile acidity         135
# citric acid               77
# residual sugar            80
# chlorides                131
# free sulfur dioxide       53
# total sulfur dioxide     138
# density                  388
# pH                        87
# sulphates                 89
# alcohol                   61
# quality                    6
# Id                      1143
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
for column in df.columns:
    plt.figure(figsize=(10,5))
    sns.boxplot(data=df,x=column)
    plt.show()

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
df_cleaned = df[~((df < (lower_bound)) | (df > (upper_bound))).any(axis=1)]

print("Shape before removing outliers:", df.shape)
print("Shape after removing outliers:", df_cleaned.shape)
# Out:
# Shape before removing outliers: (1143, 13)
# Shape after removing outliers: (834, 13)

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.barplot(y='density', data=df, palette='coolwarm',hue="quality")
plt.title("Density vs Wine Quality")
# Out:
# Text(0.5, 1.0, 'Density vs Wine Quality')

# %%
plt.subplot(1, 2, 2)
sns.barplot(hue='quality', y='fixed acidity', data=df, palette='coolwarm')
plt.title("Fixed Acidity vs Wine Quality")
# Out:
# Text(0.5, 1.0, 'Fixed Acidity vs Wine Quality')

# %%
df[['density', 'fixed acidity', 'volatile acidity', 'pH']].hist(bins=20, figsize=(10, 8), color='c')
plt.suptitle("Distribution of Density, Acidity, and pH")
plt.show()

# %%
x = df[['alcohol', 'sulphates', 'pH']]
high_quality_wines = df[df['quality'] >= 6]

print("These are high quality wines",high_quality_wines)
# Out:
# These are high quality wines       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 12              8.5              0.28         0.56             1.8      0.092
# 13              7.9              0.32         0.51             1.8      0.341
# ...             ...               ...          ...             ...        ...
# 1136            6.3              0.55         0.15             1.8      0.077
# 1137            5.4              0.74         0.09             1.7      0.089
# 1138            6.3              0.51         0.13             2.3      0.076
# 1139            6.8              0.62         0.08             1.9      0.068
# 1141            5.9              0.55         0.10             2.2      0.062
#
# ...

# %%
sns.barplot(hue='quality', y='volatile acidity', data=df, palette='coolwarm')
plt.title('Volatile Acidity vs Wine Quality')
plt.show()

# %%
sns.barplot(hue='quality', y='pH', data=df,palette='coolwarm')
plt.title('pH vs Wine Quality')
plt.show()

# %%
df['quality_label'] = df['quality'].apply(lambda x: 'good' if x >= 6 else 'bad')

sns.countplot(x='quality_label', data=df)
plt.title('Distribution of Wine Quality Labels (Good vs Bad)')
plt.show()
